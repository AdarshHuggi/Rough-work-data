# %%
#df = pd. read_csv("emp1.csv", index_col=["SNo"])
#print(df)
#here we are assigning the slno to index column

# %%
#import numpy as np
#df = pd.read.csv("emp1.csv",dtype ={'Salary':np.float64})
#print(df.dtypes)
#df

# %%
#df[Salary].max()

# %%
#df['Salary'].min()

# %%
#df['Salary'].plot()

# %%
import pandas as pd
df = pd.read_csv('C:\\Users\\adarshkumar\\Desktop\\boot_camp\\order.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-5846bde1700e> in <module>
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('C:\\Users\\adarshkumar\\Desktop\\boot_camp\\order.csv')
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
df.head()

# %%
df['Zip'].max()

# %%
import numpy as np
df = pd.read_csv('C:\\Users\\adarshkumar\\Desktop\\boot_camp\\Records.csv', dtype={'Zip':np.float64})
print(df.dtypes)

# %%
df['Zip'].plot()

# %%
df1 = pd.DataFrame(data=df)

# %%
df.loc[:,'Zip']

# %%
df=pd.read_csv('C:\\Users\\adarshkumar\\Desktop\\boot_camp\\Orders.csv')

# %%
df.head()
# Out:
#    Order ID  Order Date  Order Quantity      Sales       Ship Mode   Profit  \
# 0       3.0  10/13/2010             6.0   261.5400     Regular Air  -213.25
# 1       6.0   2/20/2012             2.0     6.9300     Regular Air    -4.64
# 2      32.0   7/15/2011            26.0  2808.0800     Regular Air  1054.82
# 3      32.0   7/15/2011            24.0  1761.4000  Delivery Truck -1748.56
# 4      32.0   7/15/2011            23.0   160.2335     Regular Air   -85.13
#
#    Unit Price       Customer Name Customer Segment Product Category
# 0       38.94  Muhammed MacIntyre   Small Business  Office Supplies
# 1        2.08         Ruben Dartt        Corporate  Office Supplies
# 2      107.53       Liz Pelletier        Corporate        Furniture
# 3       70.89       Liz Pelletier        Corporate        Furniture
# 4        7.99       Liz Pelletier        Corporate       Technology

# %%
df['Sales'].plot()

# %%
df1= pd.DataFrame(data =df)

# %%
#df1.loc[:,'Sales']

# %%
#df1.loc[:,['Customer Name','sales']]

# %%
#df1.iloc[:,1:3]

# %%
#df1.iloc[:,-3:-1]

# %%
#df1.iloc[:,-4:-1]

# %%
#df1['Order Quantity'].unique()

# %%
df1['Ship Mode'].unique()
# Out:
# array(['Regular Air', 'Delivery Truck', 'Express Air', nan], dtype=object)

# %%
df['Customer Name'].describe()
# Out:
# count           1007
# unique           430
# top       Todd Boyes
# freq              10
# Name: Customer Name, dtype: object

# %%
df1.describe()
# Out:
#           Order ID  Order Quantity         Sales        Profit   Unit Price
# count  1007.000000     1007.000000    999.000000    999.000000  1007.000000
# mean   3478.923535       24.832175   1869.035668    216.914575    91.255045
# std    2119.704215       14.367466   3851.570257   1135.726456   294.993321
# min       3.000000        1.000000      2.240000  -4266.090000     1.260000
# 25%    1665.500000       12.000000    132.465000    -83.495000     6.480000
# 50%    3456.000000       25.000000    412.620000     -1.250000    20.970000
# 75%    5350.000000       38.000000   1695.515000    146.610000    95.950000
# max    7239.000000       50.000000  45923.760000  11535.280000  6783.020000

# %%
df
# Out:
#       Order ID  Order Date  Order Quantity      Sales       Ship Mode  \
# 0          3.0  10/13/2010             6.0   261.5400     Regular Air
# 1          6.0   2/20/2012             2.0     6.9300     Regular Air
# 2         32.0   7/15/2011            26.0  2808.0800     Regular Air
# 3         32.0   7/15/2011            24.0  1761.4000  Delivery Truck
# 4         32.0   7/15/2011            23.0   160.2335     Regular Air
# 5         32.0   7/15/2011            15.0   140.5600     Regular Air
# 6         35.0  10/22/2011            30.0   288.5600     Regular Air
# 7         35.0  10/22/2011            14.0  1892.8480     Regular Air
# 8         36.0   11/2/2011            46.0  2484.7455     Regular Air
# 9         65.0   3/17/2011            32.0  3812.7300     Regular Air
# 10        32.0   7/15/2008            26.0        NaN     Regular Air
# 11        32.0   7/15/2008            24.0        NaN  Delivery Truck
# ...

# %%
df1.columns
# Out:
# Index(['Order ID', 'Order Date', 'Order Quantity', 'Sales', 'Ship Mode',
#        'Profit', 'Unit Price', 'Customer Name', 'Customer Segment',
#        'Product Category'],
#       dtype='object')

# %%
df2 =df1.drop([14,18,15,2,3])
df2
# Out:
#       Order ID  Order Date  Order Quantity      Sales       Ship Mode  \
# 0          3.0  10/13/2010             6.0   261.5400     Regular Air
# 1          6.0   2/20/2012             2.0     6.9300     Regular Air
# 4         32.0   7/15/2011            23.0   160.2335     Regular Air
# 5         32.0   7/15/2011            15.0   140.5600     Regular Air
# 6         35.0  10/22/2011            30.0   288.5600     Regular Air
# 7         35.0  10/22/2011            14.0  1892.8480     Regular Air
# 8         36.0   11/2/2011            46.0  2484.7455     Regular Air
# 9         65.0   3/17/2011            32.0  3812.7300     Regular Air
# 10        32.0   7/15/2008            26.0        NaN     Regular Air
# 11        32.0   7/15/2008            24.0        NaN  Delivery Truck
# 12        32.0   7/15/2008            23.0        NaN     Regular Air
# 13        32.0   7/15/2008            15.0        NaN     Regular Air
# ...

# %%
#df1.drop([45,78,89],inplace =True)
#df1

# %%
#deleting column form data set
df3 =df1.drop('Order ID',axis=1)

# %%
#df3

# %%
#delating column in original data set 
df3 =df1.drop('Order ID',axis=1, inplace =True)

# %%
#df1

# %%
#DATA munging 


#data munging ,you can convert a particular data into a different formate
#for exxamplee csv convert it into  html file

# %%
import pandas as pd 
orders= pd.read_csv('C:\\Users\\adarshkumar\\Desktop\\boot_camp\\Orders.csv')

orders.to_html('C:\\Users\\adarshkumar\\Desktop\\boot_camp\\OrdersHTML.html')

# %%
#Pandas 

import pandas as pd
ds =pd.read_csv('service_dataset.csv')

# %%
#ds

# %%
ds['Complaint Type']
# Out:
# 0      Noise - Street/Sidewalk
# 1              Illegal Parking
# 2           Noise - Commercial
# 3              Noise - Vehicle
# 4                       Rodent
# 5           Noise - Commercial
# 6             Blocked Driveway
# 7           Noise - Commercial
# 8           Noise - Commercial
# 9           Noise - Commercial
# 10    Noise - House of Worship
# 11          Noise - Commercial
# 12             Illegal Parking
# 13             Noise - Vehicle
# 14                      Rodent
# 15    Noise - House of Worship
# 16     Noise - Street/Sidewalk
# 17             Illegal Parking
# 18      Street Light Condition
# 19          Noise - Commercial
# 20    Noise - House of Worship
# 21          Noise - Commercial
# 22             Noise - Vehicle
# 23          Noise - Commercial
# 24            Blocked Driveway
# 25     Noise - Street/Sidewalk
# 26      Street Light Condition
# 27        Harboring Bees/Wasps
# 28     Noise - Street/Sidewalk
# 29      Street Light Condition
# ...

# %%
#to see first five rows
ds[0:5]
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    26589651  10/31/2013 02:08:41 AM                     NaN   NYPD
# 1    26593698  10/31/2013 02:01:04 AM                     NaN   NYPD
# 2    26594139  10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM   NYPD
# 3    26595721  10/31/2013 01:56:23 AM  10/31/2013 02:21:48 AM   NYPD
# 4    26590930  10/31/2013 01:53:44 AM                     NaN  DOHMH
#
#                                Agency Name           Complaint Type  \
# 0          New York City Police Department  Noise - Street/Sidewalk
# 1          New York City Police Department          Illegal Parking
# 2          New York City Police Department       Noise - Commercial
# 3          New York City Police Department          Noise - Vehicle
# 4  Department of Health and Mental Hygiene                   Rodent
#
#                      Descriptor        Location Type  Incident Zip  \
# 0                  Loud Talking      Street/Sidewalk       11432.0
# ...

# %%
ds['Complaint Type'][:5]
# Out:
# 0    Noise - Street/Sidewalk
# 1            Illegal Parking
# 2         Noise - Commercial
# 3            Noise - Vehicle
# 4                     Rodent
# Name: Complaint Type, dtype: object

# %%
ds[['Complaint Type', 'Descriptor']][:7]
# Out:
#             Complaint Type                    Descriptor
# 0  Noise - Street/Sidewalk                  Loud Talking
# 1          Illegal Parking  Commercial Overnight Parking
# 2       Noise - Commercial              Loud Music/Party
# 3          Noise - Vehicle                Car/Truck Horn
# 4                   Rodent  Condition Attracting Rodents
# 5       Noise - Commercial              Banging/Pounding
# 6         Blocked Driveway                     No Access

# %%
ds['Complaint Type'].value_counts()
# Out:
# Noise - Commercial          15
# Noise - Street/Sidewalk      6
# Blocked Driveway             5
# Noise - House of Worship     4
# Illegal Parking              3
# Noise - Vehicle              3
# Street Light Condition       3
# Taxi Complaint               2
# Rodent                       2
# Traffic Signal Condition     2
# Homeless Encampment          1
# Harboring Bees/Wasps         1
# Noise - Park                 1
# Food Establishment           1
# Name: Complaint Type, dtype: int64

# %%
cc1= ds['Complaint Type'].value_counts()

# %%
cc1[:6]
# Out:
# Noise - Commercial          15
# Noise - Street/Sidewalk      6
# Blocked Driveway             5
# Noise - House of Worship     4
# Illegal Parking              3
# Noise - Vehicle              3
# Name: Complaint Type, dtype: int64

# %%
cc1[:20].plot(kind ='bar')
