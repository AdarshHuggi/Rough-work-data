# %%
import pandas as pd 
import numpy as np

# suppose you want to change the index header you can use below "header=0"
#prase_date function used to change data type to Date data type

#df = pd.read_csv('file.csv',index_col='name_of_col', header =0, names =['e_name','e_id','e_sal'], parse_dates=['Hiredate'])

# %%
df = pd.read_csv('F:\DATA SCIENCE\hrdata.csv')
print(df)
# Out:
#              Name  HireDate   Salary  StickDaysremaining
# 0  Graham chapman  03/15/14  50000.0                  10
# 1     jhon cleese  06/01/15  65000.0                   8
# 2       Eric idle  05/12/14  45000.0                  10
# 3     terry jones  05/01/13  70000.0                   3
# 4    terry gillan  06/12/14  48000.0                   7
# 5   Micheal palin  05/13/13  66000.0                   8

# %%
print(type(df['HireDate'][0]))
#date is displaying the string datatype
# Out:
# <class 'str'>

# %%
#pase_date will change into date data type

df=pd.read_csv('hrdata.csv',index_col='Name',parse_dates=['HireDate'])
print(df)
# Out:
#                  HireDate   Salary  StickDaysremaining
# Name
# Graham chapman 2014-03-15  50000.0                  10
# jhon cleese    2015-06-01  65000.0                   8
# Eric idle      2014-05-12  45000.0                  10
# terry jones    2013-05-01  70000.0                   3
# terry gillan   2014-06-12  48000.0                   7
# Micheal palin  2013-05-13  66000.0                   8

# %%
#Hire data changed to timestamp
print(type(df['HireDate'][0]))
print(type(df['HireDate'][2]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
pandas.read_csv?
# Out:
# Object `pandas.read_csv` not found.

# %%
import pandas
#secpilictly pass "header =0" to be able to replace the existing columns name 

df =pandas.read_csv('F:\DATA SCIENCE\hrdata.csv',
                   index_col = 'Employee',
                   parse_dates = ['Hired'],
                   header =0,
                   names = ['Employee', 'Hired','Salary','Sick Days'])
print(df)
# Out:
#                     Hired   Salary  Sick Days
# Employee
# Graham chapman 2014-03-15  50000.0         10
# jhon cleese    2015-06-01  65000.0          8
# Eric idle      2014-05-12  45000.0         10
# terry jones    2013-05-01  70000.0          3
# terry gillan   2014-06-12  48000.0          7
# Micheal palin  2013-05-13  66000.0          8

# %%
#writing the CSV files with pandas 
df
df.to_csv('F:\DATA SCIENCE\hrdata_modified.csv')

# %%
dfh =pd.read_csv('F:\DATA SCIENCE\hrdata_modified.csv')
dfh
# Out:
#          Employee       Hired   Salary  Sick Days
# 0  Graham chapman  2014-03-15  50000.0         10
# 1     jhon cleese  2015-06-01  65000.0          8
# 2       Eric idle  2014-05-12  45000.0         10
# 3     terry jones  2013-05-01  70000.0          3
# 4    terry gillan  2014-06-12  48000.0          7
# 5   Micheal palin  2013-05-13  66000.0          8

# %%
dfh['Salary'].plot.bar()

# %%
dfh['Salary'].min()
# Out:
# 45000.0

# %%
import pandas as pd

df=pd.read_csv('F:\DATA SCIENCE\empl.csv')
print(df)
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df=pd.read_csv('F:\DATA SCIENCE\empl.csv',index_col=['SNo'])
print(df)
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# ...

# %%
import numpy as np
df =pd.read_csv('empl.csv',dtype={'Salary':np.float64})
print(df.dtypes)
df
# Out:
# SNo         int64
# Name       object
# Age       float64
# City       object
# Salary    float64
# dtype: object
#     SNo    Name   Age       City   Salary
# 0     1     Tom  28.0    Toronto  20000.0
# 1     2     Lee  31.0    Edmonto   3900.0
# 2     3    Dave  34.0    Toronto   8000.0
# 3     4    Anik  26.0   HongKong  66672.0
# 4     5   kamal  30.0    BayArea  34344.0
# 5     6    Geet  22.0   HongKong  30007.0
# 6     7  Steven  43.0    BayArea   8300.0
# 7     8     Ram  38.0  Hyderabad  54666.0
# 8     9    hari  50.0    newyork  67666.0
# 9    11    yami  27.0    newyork   8888.0
# 10   12    Anik  26.0   HongKong  66672.0
# 11   13   kamal  30.0    BayArea  34344.0
# 12   14    Geet  22.0   HongKong  30007.0
# 13   15  Steven  43.0    BayArea   8300.0
# 14   16     Ram  38.0  Hyderabad  54666.0
# 15   17    hari   NaN    newyork  67666.0
# 16   18    yami  27.0    newyork   8888.0
# 17   19     Lee  31.0    Edmonto      NaN

# %%
df['Salary'].max()
# Out:
# 67666.0

# %%
df['Salary'].min()
# Out:
# 3900.0

# %%
df['Salary'].plot()

# %%
df1=pd.DataFrame(data=df)

# %%
df1.loc[:,'Salary']
# Out:
# 0     20000.0
# 1      3900.0
# 2      8000.0
# 3     66672.0
# 4     34344.0
# 5     30007.0
# 6      8300.0
# 7     54666.0
# 8     67666.0
# 9      8888.0
# 10    66672.0
# 11    34344.0
# 12    30007.0
# 13     8300.0
# 14    54666.0
# 15    67666.0
# 16     8888.0
# 17        NaN
# Name: Salary, dtype: float64

# %%
df1.loc[:,['Name','Salary']]
# Out:
#       Name   Salary
# 0      Tom  20000.0
# 1      Lee   3900.0
# 2     Dave   8000.0
# 3     Anik  66672.0
# 4    kamal  34344.0
# 5     Geet  30007.0
# 6   Steven   8300.0
# 7      Ram  54666.0
# 8     hari  67666.0
# 9     yami   8888.0
# 10    Anik  66672.0
# 11   kamal  34344.0
# 12    Geet  30007.0
# 13  Steven   8300.0
# 14     Ram  54666.0
# 15    hari  67666.0
# 16    yami   8888.0
# 17     Lee      NaN

# %%
df1.iloc[:,1:3]
# Out:
#       Name   Age
# 0      Tom  28.0
# 1      Lee  31.0
# 2     Dave  34.0
# 3     Anik  26.0
# 4    kamal  30.0
# 5     Geet  22.0
# 6   Steven  43.0
# 7      Ram  38.0
# 8     hari  50.0
# 9     yami  27.0
# 10    Anik  26.0
# 11   kamal  30.0
# 12    Geet  22.0
# 13  Steven  43.0
# 14     Ram  38.0
# 15    hari   NaN
# 16    yami  27.0
# 17     Lee  31.0

# %%
df1.iloc[:,0:4]
# Out:
#     SNo    Name   Age       City
# 0     1     Tom  28.0    Toronto
# 1     2     Lee  31.0    Edmonto
# 2     3    Dave  34.0    Toronto
# 3     4    Anik  26.0   HongKong
# 4     5   kamal  30.0    BayArea
# 5     6    Geet  22.0   HongKong
# 6     7  Steven  43.0    BayArea
# 7     8     Ram  38.0  Hyderabad
# 8     9    hari  50.0    newyork
# 9    11    yami  27.0    newyork
# 10   12    Anik  26.0   HongKong
# 11   13   kamal  30.0    BayArea
# 12   14    Geet  22.0   HongKong
# 13   15  Steven  43.0    BayArea
# 14   16     Ram  38.0  Hyderabad
# 15   17    hari   NaN    newyork
# 16   18    yami  27.0    newyork
# 17   19     Lee  31.0    Edmonto

# %%
df1.iloc[:,-1]
# Out:
# 0     20000.0
# 1      3900.0
# 2      8000.0
# 3     66672.0
# 4     34344.0
# 5     30007.0
# 6      8300.0
# 7     54666.0
# 8     67666.0
# 9      8888.0
# 10    66672.0
# 11    34344.0
# 12    30007.0
# 13     8300.0
# 14    54666.0
# 15    67666.0
# 16     8888.0
# 17        NaN
# Name: Salary, dtype: float64

# %%
df1.iloc[1:4,-1]
# Out:
# 1     3900.0
# 2     8000.0
# 3    66672.0
# Name: Salary, dtype: float64

# %%
df1.count()
# Out:
# SNo       18
# Name      18
# Age       17
# City      18
# Salary    17
# dtype: int64

# %%
#count gives total number of counts 
df1['Name'].count()
# Out:
# 18

# %%
df1['Name'].unique()
df
# Out:
#     SNo    Name   Age       City   Salary
# 0     1     Tom  28.0    Toronto  20000.0
# 1     2     Lee  31.0    Edmonto   3900.0
# 2     3    Dave  34.0    Toronto   8000.0
# 3     4    Anik  26.0   HongKong  66672.0
# 4     5   kamal  30.0    BayArea  34344.0
# 5     6    Geet  22.0   HongKong  30007.0
# 6     7  Steven  43.0    BayArea   8300.0
# 7     8     Ram  38.0  Hyderabad  54666.0
# 8     9    hari  50.0    newyork  67666.0
# 9    11    yami  27.0    newyork   8888.0
# 10   12    Anik  26.0   HongKong  66672.0
# 11   13   kamal  30.0    BayArea  34344.0
# 12   14    Geet  22.0   HongKong  30007.0
# 13   15  Steven  43.0    BayArea   8300.0
# 14   16     Ram  38.0  Hyderabad  54666.0
# 15   17    hari   NaN    newyork  67666.0
# 16   18    yami  27.0    newyork   8888.0
# 17   19     Lee  31.0    Edmonto      NaN

# %%
df1['City'].nunique() #gives the number of unique city
# Out:
# 6

# %%
df1['City'].unique()
# Out:
# array(['Toronto', 'Edmonto', 'HongKong', 'BayArea', 'Hyderabad',
#        'newyork'], dtype=object)

# %%
print(df1['Name'].describe())
# Out:
# count       18
# unique      10
# top       yami
# freq         2
# Name: Name, dtype: object

# %%
df1.describe()
# Out:
#              SNo        Age        Salary
# count  18.000000  17.000000     17.000000
# mean   10.000000  32.117647  33705.058824
# std     5.790459   7.865132  24554.462953
# min     1.000000  22.000000   3900.000000
# 25%     5.250000  27.000000   8888.000000
# 50%    10.000000  30.000000  30007.000000
# 75%    14.750000  38.000000  54666.000000
# max    19.000000  50.000000  67666.000000

# %%
# include= all will take all data includeing the numeric, string , float  cloumn

df1.describe(include='all')
# Out:
#               SNo  Name        Age     City        Salary
# count   18.000000    18  17.000000       18     17.000000
# unique        NaN    10        NaN        6           NaN
# top           NaN  yami        NaN  newyork           NaN
# freq          NaN     2        NaN        4           NaN
# mean    10.000000   NaN  32.117647      NaN  33705.058824
# std      5.790459   NaN   7.865132      NaN  24554.462953
# min      1.000000   NaN  22.000000      NaN   3900.000000
# 25%      5.250000   NaN  27.000000      NaN   8888.000000
# 50%     10.000000   NaN  30.000000      NaN  30007.000000
# 75%     14.750000   NaN  38.000000      NaN  54666.000000
# max     19.000000   NaN  50.000000      NaN  67666.000000

# %% [markdown]
# #dropings of rows and columns in pandas

# %%
df1.columns
# Out:
# Index(['SNo', 'Name', 'Age', 'City', 'Salary'], dtype='object')

# %%
df2=df1.drop([14,15,16,17])
df2
# Out:
#     SNo    Name   Age       City   Salary
# 0     1     Tom  28.0    Toronto  20000.0
# 1     2     Lee  31.0    Edmonto   3900.0
# 2     3    Dave  34.0    Toronto   8000.0
# 3     4    Anik  26.0   HongKong  66672.0
# 4     5   kamal  30.0    BayArea  34344.0
# 5     6    Geet  22.0   HongKong  30007.0
# 6     7  Steven  43.0    BayArea   8300.0
# 7     8     Ram  38.0  Hyderabad  54666.0
# 8     9    hari  50.0    newyork  67666.0
# 9    11    yami  27.0    newyork   8888.0
# 10   12    Anik  26.0   HongKong  66672.0
# 11   13   kamal  30.0    BayArea  34344.0
# 12   14    Geet  22.0   HongKong  30007.0
# 13   15  Steven  43.0    BayArea   8300.0

# %%
#df1.drop([14,15,16,17], inplace=True)
df1
# Out:
#     SNo    Name   Age       City   Salary
# 0     1     Tom  28.0    Toronto  20000.0
# 1     2     Lee  31.0    Edmonto   3900.0
# 2     3    Dave  34.0    Toronto   8000.0
# 3     4    Anik  26.0   HongKong  66672.0
# 4     5   kamal  30.0    BayArea  34344.0
# 5     6    Geet  22.0   HongKong  30007.0
# 6     7  Steven  43.0    BayArea   8300.0
# 7     8     Ram  38.0  Hyderabad  54666.0
# 8     9    hari  50.0    newyork  67666.0
# 9    11    yami  27.0    newyork   8888.0
# 10   12    Anik  26.0   HongKong  66672.0
# 11   13   kamal  30.0    BayArea  34344.0
# 12   14    Geet  22.0   HongKong  30007.0
# 13   15  Steven  43.0    BayArea   8300.0

# %%
#df3 =df1.drop('Name', axis =1) #droping the colums using axis=1
df3                         #droping the rows axis =0
# Out:
#     SNo   Age       City   Salary
# 0     1  28.0    Toronto  20000.0
# 1     2  31.0    Edmonto   3900.0
# 2     3  34.0    Toronto   8000.0
# 3     4  26.0   HongKong  66672.0
# 4     5  30.0    BayArea  34344.0
# 5     6  22.0   HongKong  30007.0
# 6     7  43.0    BayArea   8300.0
# 7     8  38.0  Hyderabad  54666.0
# 8     9  50.0    newyork  67666.0
# 9    11  27.0    newyork   8888.0
# 10   12  26.0   HongKong  66672.0
# 11   13  30.0    BayArea  34344.0
# 12   14  22.0   HongKong  30007.0
# 13   15  43.0    BayArea   8300.0

# %%
df1.drop(['Name','Salary'], axis=1, inplace= True)
df1
# Out:
#     SNo   Age       City
# 0     1  28.0    Toronto
# 1     2  31.0    Edmonto
# 2     3  34.0    Toronto
# 3     4  26.0   HongKong
# 4     5  30.0    BayArea
# 5     6  22.0   HongKong
# 6     7  43.0    BayArea
# 7     8  38.0  Hyderabad
# 8     9  50.0    newyork
# 9    11  27.0    newyork
# 10   12  26.0   HongKong
# 11   13  30.0    BayArea
# 12   14  22.0   HongKong
# 13   15  43.0    BayArea

# %% [markdown]
# # Data Munging
# in Data munging , you can convert a particular data into a diffrent format. for example  if you can convert it into  .html  or anyother data file format ass well

# %%
import pandas as pd
country =pd.read_csv('F:\DATA SCIENCE\empl.csv',index_col=0)
country.to_html('F:\DATA SCIENCE\empltest.html')
