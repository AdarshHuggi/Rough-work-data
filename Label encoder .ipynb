# %%
#label Enocder and simple imputer , one hot encoder
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
from sklearn.matrics import accuracy_score
from sklearn.matrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
from scipy.stats import zscore
import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-dc3f316fe783> in <module>
#       6 import matplotlib.pyplot as plt
#       7 import sklearn
# ----> 8 from sklearn.matrics import accuracy_score
#       9 from sklearn.matrics import confusion_matrix,classification_report
#      10 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'sklearn.matrics'

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
ds=pd.read_csv('age_salary.csv')

# %%
ds
# Out:
#    index   Nation purchased_item   salary   age
# 0      0    India             No  66777.0  23.0
# 1      1   Russia            Yes  87878.0  24.0
# 2      2  Germany             No  34559.0   NaN
# 3      3    India            Yes  40000.0  26.0
# 4      4  Germany            Yes      NaN  21.0
# 5      5   Russia             No  45000.0   NaN
# 6      6  Germany            Yes  89993.0  62.0
# 7      7    India             No  55555.0  24.0
# 8      8   Russia            Yes      NaN  45.0
# 9      9  Germany            Yes  67222.0  53.0

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
# index             10 non-null int64
# Nation            10 non-null object
# purchased_item    10 non-null object
# salary            8 non-null float64
# age               8 non-null float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 480.0+ bytes

# %%
import csv
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression 
import matplotlib.pyplot as plt
from sklearn import metrics

# %%
#pd.read_csv?

# %%
ds=pd.read_csv('empl.csv')
ds
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
ds.describe()
# Out:
#              SNo        Age        Salary
# count  22.000000  19.000000     19.000000
# mean   12.090909  32.421053  33739.947368
# std     6.927578   7.174924  23151.188084
# min     1.000000  22.000000   3900.000000
# 25%     6.250000  27.000000   8888.000000
# 50%    12.500000  31.000000  33451.000000
# 75%    17.750000  36.000000  54666.000000
# max    23.000000  50.000000  67666.000000

# %%
ds.dtypes
# Out:
# SNo          int64
# Name        object
# Age        float64
# City        object
# Country     object
# Salary     float64
# dtype: object

# %%
df1 =ds.drop(['Name'], axis=1)
#df1

# %%
ds
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
import seaborn as sns
sns.heatmap(ds.isnull())

# %%
ds.isnull().sum()
# Out:
# SNo        0
# Name       0
# Age        3
# City       3
# Country    0
# Salary     3
# dtype: int64

# %%
#ds.dropna(axis=0, inplace= True)

# %%
df=ds

# %%
#!pip intall sklearn-pandas
#sklearn-pandas has CategoricalImputer

# %%
#sklearn,impute SimpleImputer class works for imputing 

from sklearn.impute import SimpleImputer
imp = SimpleImputer(strategy="most_frequent")
df['City']=imp.fit_transform(df['City'].values.reshape(-1,1))
df
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0   HongKong  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0   HongKong  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0   HongKong  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df['Age'].shape
# Out:
# (22,)

# %%
#df['Age']=df['Age'].values.reshape(-1,1)
#df['Age'].shape

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values =np.nan, strategy='mean')

df['Age']=imp.fit_transform(df['Age'].values.reshape(-1,1))
df['Salary']=imp.fit_transform(df['Salary'].values.reshape(-1,1))

#imputer works for numerical data such as age and salary

# %%
df
# Out:
#     SNo    Name        Age       City  Country        Salary
# 0     1     Tom  28.000000    Toronto   Canada  20000.000000
# 1     2     Lee  31.000000    Edmonto   Canada   3900.000000
# 2     3    Dave  34.000000    Toronto   Canada   8000.000000
# 3     4    Anik  26.000000   HongKong     Asia  66672.000000
# 4     5   kamal  30.000000   HongKong  America  33739.947368
# 5     6    Geet  32.421053   HongKong     Asia  30007.000000
# 6     7  Steven  43.000000    BayArea  America   8300.000000
# 7     8     Ram  38.000000  Hyderabad     Asia  54666.000000
# 8     9    hari  50.000000    newyork  America  67666.000000
# 9    11    yami  32.421053    newyork  America   8888.000000
# 10   12    Anik  26.000000   HongKong     Asia  66672.000000
# 11   13   kamal  30.000000   HongKong  America  34344.000000
# 12   14    Geet  22.000000   HongKong     Asia  30007.000000
# 13   15  Steven  43.000000   HongKong  America   8300.000000
# ...

# %%
le =LabelEncoder()
#df['City'] =le.fit_transform(df['City'])

list1=['City','Country']
for val in list1:
    df[val]=le.fit_transform(df[val].astype(str))

# %%
df
# Out:
#     SNo    Name        Age  City  Country        Salary
# 0     1     Tom  28.000000     8        3  20000.000000
# 1     2     Lee  31.000000     3        3   3900.000000
# 2     3    Dave  34.000000     8        3   8000.000000
# 3     4    Anik  26.000000     5        2  66672.000000
# 4     5   kamal  30.000000     5        1  33739.947368
# 5     6    Geet  32.421053     5        2  30007.000000
# 6     7  Steven  43.000000     1        1   8300.000000
# 7     8     Ram  38.000000     6        2  54666.000000
# 8     9    hari  50.000000     9        1  67666.000000
# 9    11    yami  32.421053     9        1   8888.000000
# 10   12    Anik  26.000000     5        2  66672.000000
# 11   13   kamal  30.000000     5        1  34344.000000
# 12   14    Geet  22.000000     5        2  30007.000000
# 13   15  Steven  43.000000     5        1   8300.000000
# 14   16     Ram  38.000000     6        2  54666.000000
# 15   17    hari  32.421053     9        1  67666.000000
# ...

# %%
#now we can see t 4 ,11 and 13 row filled with 9 ,Null is replaced with 9
#replace 9 with NaN ans replace it with most frequest calue

# %% [markdown]
# import numpy
# df['City'].replace(9, numpy.NaN,inplace =True)
# df
#
# methods
#
# #for column
# df['column'] = df['coulman'].replace(np.nan,0)
#
# df['age']=df['age'].replace(np.nan,df['age'].mean())
#
# #for whole dataframe
# df=df.replace(np.Nan, df.mean())
#
#
# #inplace
# df.replace(np.nan,0,implace=True)
#
# df.replace(-1,np.Nan,inplace=True)
# df.replace(-1,df.mean(),inplace=True)
#
# #filling string columns: when string column have missing
