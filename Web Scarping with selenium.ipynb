# %%
#import the libraries
#!pip  install selenium
#!pip install webdriver_manager
import selenium
import pandas as pd
from selenium import webdriver
import time

# %%
#lets frist connect the web driver
driver = webdriver.Chrome("chromedriver.exe")

# %% [markdown]
# Q1: Write a python program to scrape data for “Data Analyst” Job position in
# “Bangalore” location. You have to scrape the job-title, job-location, company_name,
# experience_required. You have to scrape first 10 jobs data.

# %%
#1. first get the webpage https://www.naukri.com/ 
url ="https://www.naukri.com/"
driver.get(url)

# %%
#finding the element for job search bar

search_job = driver.find_element_by_id('qsb-keyword-sugg')
search_loc = driver.find_element_by_id('qsb-location-sugg')

# %%
# 2. Enter “Data Analyst” in “Skill,Designations,Companies” field and enter “Bangalore” in “enter the location” field. 
search_job.send_keys("Data Analyst")
search_loc.send_keys("Bangalore")

#selecting search button 
search_btn =driver.find_element_by_xpath("//button[@class='btn']")

# do click using xpath function
search_btn.click()

# %%
#scraping the titles of the job
job_titles = []
location_tags =[]
experience_tags=[]
Company_name=[]

for i in driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']"):
    job_titles.append(i.text)
    
for i in driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span"):
    location_tags.append(i.text)
     
for i in driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi experience'] //span"):
    experience_tags.append(i.text)

for i in driver.find_elements_by_xpath("//a[@class ='subTitle ellipsis fleft']"):
    Company_name.append(i.text)



#creating the dataframe of top 10 job results 
    
Job_Details =pd.DataFrame({ })

Job_Details['job_titles']= job_titles[:10]
Job_Details['Job_location'] = location_tags[:10]
Job_Details['experience'] =experience_tags[0:10]
Job_Details['Company_name'] =Company_name[0:10]
Job_Details
# Out:
#                                           job_titles  \
# 0            Business Data Analyst - MIS & Reporting
# 1                 Senior Data Analyst - Data Lineage
# 2                     Data Analyst - Informatica MDM
# 3                                       Data Analyst
# 4                                       Data Analyst
# 5   Excel VBA Jobs Bangalore | VBA data analyst Jobs
# 6  Data Analyst (2positions)//immediate Joiners//...
# 7                     Business/Data Analyst - SSE/LA
# 8                              Business Data Analyst
# 9                                       Data Analyst
#
#                                         Job_location experience  \
# 0                        Mumbai, Bangalore/Bengaluru    3-8 Yrs
# 1                                Bangalore/Bengaluru   5-10 Yrs
# 2                                Bangalore/Bengaluru    6-9 Yrs
# 3  Noida, Kolkata, Hyderabad/Secunderabad, Pune, ...    0-2 Yrs
# ...

# %% [markdown]
# #### 2. Write a python program to scrape data for “Data Scientist” Job position in
#  Bangalore” location.You have to scrape the job-title, job-location,
# company_name, full job-description. You have to scrape first 10 jobs data"""

# %%
#1. first get the webpage https://www.naukri.com/ 
url1 ="https://www.naukri.com/"
driver.get(url1)

# %%
#finding the element for job search bar
search_job = driver.find_element_by_id('qsb-keyword-sugg')
search_loc = driver.find_element_by_id('qsb-location-sugg')

# %%
# 2. Enter “Data Analyst” in “Skill,Designations,Companies” field and enter “Bangalore” in “enter the location” field. 
search_job.send_keys("Data Scientist")
search_loc.send_keys("Bangalore")

#selecting search button 
search_btn =driver.find_element_by_xpath("//button[@class='btn']")

# do click using xpath function
search_btn.click()

# %%
#scraping the titles of the job
job_titles = []
location_tags =[]
experience_tags=[]
Company_name=[]

for i in driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']"):
    job_titles.append(i.text)
    
for i in driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span"):
    location_tags.append(i.text)
     
for i in driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi experience'] //span"):
    experience_tags.append(i.text)

for i in driver.find_elements_by_xpath("//a[@class ='subTitle ellipsis fleft']"):
    Company_name.append(i.text)



#creating the dataframe of top 10 job results 
    
Job_Details =pd.DataFrame({ })

Job_Details['job_titles']= job_titles[:10]
Job_Details['Job_location'] = location_tags[:10]
Job_Details['experience'] =experience_tags[0:10]
Job_Details['Company_name'] =Company_name[0:10]
Job_Details
# Out:
# Empty DataFrame
# Columns: [job_titles, Job_location, experience, Company_name]
# Index: []

# %%
#get all jobs URL inlks
page_urls =[]

url = driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
for i in url:
    page_urls.append(i.get_attribute('href'))

# %%
job_titles = []
Job_Descritpion =[]

for i in page_urls:
    driver.get(i)
    for j in driver.find_elements_by_xpath("//h1[@class='av-special-heading-tag']"):
        job_titles.append(j.text)
        break
    for m in driver.find_elements_by_xpath("//div[@class='clearboth description']"):
        Job_Descritpion.append(m.text)
        break
    time.sleep(2)

# %%
Job_desc =pd.DataFrame({ })

Job_desc['Job_Descritpion']= Job_Descritpion[:10]
Job_desc['job_titles'] = job_titles[:10]

Job_desc
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-118-9dc94f840aa0> in <module>
#       2
#       3 Job_desc['Job_Descritpion']= Job_Descritpion[:10]
# ----> 4 Job_desc['job_titles'] = job_titles[:10]
#       5
#       6 Job_desc
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3443
#    3444         self._ensure_valid_index(value)
# -> 3445         value = self._sanitize_column(key, value)
#    3446         NDFrame._set_item(self, key, value)
#    3447
#
# ...

# %%
# importing necessary packages
from selenium import webdriver
  
# for holding the resultant list
titles = []
Job_Descritpion =[]
  
for page in page_urls:
    #driver = webdriver.Chrome(ChromeDriverManager().install())
    driver.get(page)
    title1 = driver.find_elements_by_class_name("jd-header-title")
    title = driver.find_elements_by_class_name("av-special-heading-tag")
    job_desc = driver.find_elements_by_class_name("job-desc")
    
    for n in title1:
        titles.append([title1[n].text])

  
    for m in title:
        titles.append([title[m].text])
                       
    for j in job_desc:
        Job_Descritpion.append([job_desc[j].text])

# %%
len(titles)

# %%
#scarp the data from the multiples pages

# %%
page_urls =[]


url = driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
for i in url:
    page_urls.append(i.get_attribute('href'))
page_urls

# %%
job_titles =[]
for i in page_urls:
    driver.get(i)
    titles_tags=driver.find_elements_by_xpath("//a[@calss ='title fw500 ellipsis']")
    for i in titles_tags:
        job_titles.append(i.text)

# %%
#So lets extract the all tags having job titles

title_tags =driver.find_elements_by_xpath("//h1[@class='jd-header-title']")  
    job_titles = []

# %% [markdown]
# ## Q3: In this question you have to scrape data using the filters available on the webpage as shown below:

# %%
#lets frist connect the web driver
driver = webdriver.Chrome("chromedriver.exe")

# %%
#first get the webpage https://www.naukri.com/ 
url ="https://www.naukri.com/"
driver.get(url)

# %%
#find the search text box
search_job = driver.find_element_by_id('qsb-keyword-sugg')

# Enter “Data Scientist” in “Skill,Designations,Companies” field . 
search_job.send_keys("Data Scientist")

#Then click the search button. 
search_btn =driver.find_element_by_xpath("//button[@class='btn']")

#Click on search button 
search_btn.click()

# %%
#Then apply the location filter and salary filter by checking the respective boxes 

filter_btn_loc =driver.find_element_by_xpath("//span[@title='Delhi / NCR']")
filter_btn_loc.click()

# %%
#filtering the salary
filter_btn_sal =driver.find_element_by_xpath("//span[@title='3-6 Lakhs']")
filter_btn_sal.click()

# %%
#scraping the titles of the job
job_titles1 = []
location_tags1 =[]
experience_tags1=[]
Company_name1=[]

for i in driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']"):
    job_titles1.append(i.text)
    
for i in driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span"):
    location_tags1.append(i.text)
     
for i in driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi experience'] //span"):
    experience_tags1.append(i.text)

for i in driver.find_elements_by_xpath("//a[@class ='subTitle ellipsis fleft']"):
    Company_name1.append(i.text)



#creating the dataframe of top 10 job results 
    
Job_Details1 =pd.DataFrame({ })

Job_Details1['job_titles']= job_titles1[:10]
Job_Details1['Job_location'] = location_tags1[:10]
Job_Details1['experience'] =experience_tags1[0:10]
Job_Details1['Company_name'] =Company_name1[0:10]
Job_Details1
# Out:
#                                           job_titles  \
# 0  Data analytics / Data scientist intern (work f...
# 1                                     Data Scientist
# 2    Data Scientist / Data Analyst -Business Analyst
# 3              Chaayos is Looking For Data Scientist
# 4                              Junior Data Scientist
# 5       We are hiring- Data Scientist +Python- Noida
# 6                                     Data Scientist
# 7                                     Data Scientist
# 8                                     Data Scientist
# 9                                     Data Scientist
#
#                                         Job_location experience  \
# 0          Kolkata, Bangalore/Bengaluru, Delhi / NCR    0-5 Yrs
# 1      Mumbai, Gurgaon/Gurugram, Bangalore/Bengaluru    3-7 Yrs
# 2  Mumbai, Hyderabad/Secunderabad, Pune, Gurgaon/...    0-3 Yrs
# 3                                          New Delhi    0-5 Yrs
# ...

# %% [markdown]
# ### 4. Write a python program to scrape data for first 10 job results for Data scientist Designation in Noida location. You have to scrape company_name, No. of days ago when job was posted, Rating of the company.

# %%
#lets frist connect the web driver
driver = webdriver.Chrome("chromedriver.exe")

# %%
#first get the webpage https://www.naukri.com/ 
url ="https://www.glassdoor.co.in/index.htm"
driver.get(url)

# %%
try:
    driver.find_element_by_xpath("//button[@class='d-flex align-items-center justify-content-center order-1 order-md-2 mr-auto mr-md-0 p-0 LockedHomeHeaderStyles__signInButton']").click()
        
except:
    #spelling error making this code not work as expected
    driver.find_element_by_xpath("//div[@class='d-flex justify-content-center order-1 order-md-2 LockedHomeHeaderStyles__flexibleContainer']").click()

# %%
login = driver.find_element_by_id('userEmail')

# %%
login.send_keys("aaa.r.huggi@gmail.com")

# %%
password = driver.find_element_by_id('userPassword')

# %%
password.send_keys("adarsh1993")

# %%
from selenium.common.exceptions import NoSuchElementException

try:
    login_btn =driver.find_element_by_xpath("//button[@class='gd-ui-button minWidthBtn css-8i7bc2']")
    login_btn.click()
except NoSuchElementException as e:
    #spelling error making this code not work as expected
    print(e)
    pass


#Click on search button

# %%
col headerSearchInput css-1ohf0ui

# %%
Search_job =driver.find_element_by_xpath("//div[@class='col headerSearchInput css-1ohf0ui']")
Search_job.send_keys("Data Scientist")

Search_loc = driver.find_element_by_id('scLocation"')
Search_loc.send_keys("Noida")
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-234-e9b415f6b7fd> in <module>
# ----> 1 Search_job = driver.find_element_by_id('scKeyword')
#       2 Search_job.send_keys("Data Scientist")
#       3
#       4 Search_loc = driver.find_element_by_id('scLocation"')
#       5 Search_loc.send_keys("Noida")
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_id(self, id_)
#     358             element = driver.find_element_by_id('foo')
#     359         """
# --> 360         return self.find_element(by=By.ID, value=id_)
#     361
#     362     def find_elements_by_id(self, id_):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# ...

# %%
#find the search text box
#search_job = driver.find_element_by_id('scKeyword')

#exception block web scrap 
for i in range(2):
    try:
        driver.find_element_by_id('scKeyword').send_keys("Data Scientist")
        driver.find_element_by_id('scLocation"').send_keys("Noida")

    except:
        driver.find_element_by_xpath("//div[@class='input-wrapper css-q444d9']").send_keys("Data Scientist")
       # driver.find_element_by_xpath("//div[@class='input-wrapper css-q444d9']").send_keys("Data Scientist")
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-231-b3c92c02dcd9> in <module>
#       6     try:
# ----> 7         driver.find_element_by_id('scKeyword').send_keys("Data Scientist")
#       8         driver.find_element_by_id('scLocation"').send_keys("Noida")
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_id(self, id_)
#     359         """
# --> 360         return self.find_element(by=By.ID, value=id_)
#     361
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# ...

# %%
#find the search text box
#exception block web scrap 
for i in range(2):
    try:
        driver.find_element_by_xpath("//div[@class='input-wrapper css-q444d9']").click()
    except:
        driver.find_element_by_xpath("//a[@class='fright fs14 btn-secondary br2']/span").click()
    time.sleep(5)



#search_job = driver.find_element_by_id('class="input-wrapper css-q444d9"')
search_job =driver.find_element_by_xpath("//div[@class='input-wrapper css-q444d9']")


# Enter “Data Scientist” in “Skill,Designations,Companies” field . 
search_job.send_keys("Data Scientist")
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-200-9c3783286b51> in <module>
#       4     try:
# ----> 5         driver.find_element_by_xpath("//div[@class='input-wrapper css-q444d9']").click()
#       6     except:
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# ...

# %%
ok_btn =driver.find_element_by_xpath("//button[@class='gd-ui-button ml css-8i7bc2']")

#Click on search button 
ok_btn.click()

# %%
#Then click the search button. 
search_btn =driver.find_element_by_xpath("//button[@class='pl-0 pr-xsm SearchStyles__searchKeywordSubmit']")

#Click on search button 
search_btn.click()

# %% [markdown]
# Q6 : Scrape data of first 100 sunglasses listings on flipkart.com. You have to
# scrape four attributes:
#
# . Brand
# 2. Product Description
# 3. Price
# 4. Discount %
# The attributes which you have to scrape is ticked marked in the below image.
#
# To scrape the data you have to go through following steps:
# 1. Go to flipkart webpage by url   https://www.flipkart.com/
# 2. Enter “sunglasses” in the search field where “search for products, brands and
# more” is written and click the search icon
# 3. after that you will reach to a webpage having a lot of sunglasses. From this page
# you can scrap the required data as usual.
# 4. after scraping data from the first page, go to the “Next” Button at the bottom of
# the page , then click on it
#
# 5. Now scrape data from this page as usual
# 6. repeat this until you get data for 100 sunglasses.
# Note that all of the above steps have to be done by coding only and not manually.

# %%
#lets frist connect the web driver
driver = webdriver.Chrome("chromedriver.exe")

#first get the webpage https://www.flipkart.com/ 
url ="https://www.flipkart.com/"
driver.get(url)

# %%
close_login = driver.find_element_by_xpath("//button[@class='_2KpZ6l _2doB4z']")
close_login.click()

# %%
#searching sof sungalss in flipkart
search = driver.find_element_by_xpath("//input[@class='_3704LK']")
search.send_keys("Sunglass")

# %%
submit1 =driver.find_element_by_xpath("//button[@class='L0Z3Pu']")
submit1.click()

# %%
#get all jobs URL inlks
page_urls =[]
url = driver.find_elements_by_xpath("//a[@class='ge-49M']")
for i in url:
    page_urls.append(i.get_attribute('href'))
# Out:
# ['https://www.flipkart.com/search?q=Sunglass&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2',
#  'https://www.flipkart.com/search?q=Sunglass&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=3',
#  'https://www.flipkart.com/search?q=Sunglass&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=4',
#  'https://www.flipkart.com/search?q=Sunglass&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=5',
#  'https://www.flipkart.com/search?q=Sunglass&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=6',
#  'https://www.flipkart.com/search?q=Sunglass&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=7',
#  'https://www.flipkart.com/search?q=Sunglass&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=8',
# ...

# %%
brand_name =[]
Product_descrption =[]
Price= []
Discount= []

for j in page_urls:
    driver.get(j)
    for i in driver.find_elements_by_xpath("//div[@class='_2WkVRV']"):
        brand_name.append(i.text)
    
    for i in driver.find_elements_by_xpath("//a[@class='IRpwTa']"):
        Product_descrption.append(i.text)
    
    for i in driver.find_elements_by_xpath("//a[@class='IRpwTa']"):
        Product_descrption.append(i.text)

    for i in driver.find_elements_by_xpath("//div[@class='_30jeq3']"):
        Price.append(i.text)
    
    for i in driver.find_elements_by_xpath("//div[@class='_3Ay6Sb']"):
        Discount.append(i.text)
    time.sleep(2)

# %%
Sunglass =pd.DataFrame({ })

Sunglass['brand_name']= brand_name[:100]
Sunglass['Product_descrption'] = Product_descrption[:100]
Sunglass['Price'] =Price[:100]
Sunglass['Discount'] =Discount[:100]
Sunglass
# Out:
#           brand_name                                 Product_descrption  \
# 0           Fastrack             UV Protection Wayfarer Sunglasses (56)
# 1             PIRASO            UV Protection Butterfly Sunglasses (65)
# 2           elegante         UV Protection Round Sunglasses (Free Size)
# 3              povty      UV Protection Wayfarer Sunglasses (Free Size)
# 4           Fastrack   UV Protection Wrap-around Sunglasses (Free Size)
# 5   Cristiano Ronnie  UV Protection, Riding Glasses Aviator Sunglass...
# 6              NuVew              UV Protection Aviator Sunglasses (58)
# 7          ROYAL SON     Polarized, UV Protection Round Sunglasses (49)
# 8          ROYAL SON         UV Protection Retro Square Sunglasses (58)
# 9             AISLIN  UV Protection, Gradient Butterfly, Retro Squar...
# 10        PHENOMENAL  UV Protection, Mirrored Retro Square Sunglasse...
# 11      Singco India  Mirrored, UV Protection, Riding Glasses, Other...
# ...

# %% [markdown]
# ### Q7: Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to
#
# As shown in the above page you have to scrape the tick marked attributes.
# These are
# 1. Rating
# 2. Review_summary
# 3. Full review
# You have to scrape this data for first 100 reviews.

# %%
#lets frist connect the web driver
driver = webdriver.Chrome("chromedriver.exe")
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/p/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace")
All_review =driver.find_element_by_xpath("//div[@class='_3UAT2v _16PBlm']")
#Click on search button 
All_review.click()

# %%
#get all jobs URL inlks
page_urls =[]

url = driver.find_elements_by_xpath("//a[@class='ge-49M']")
for i in url:
    page_urls.append(i.get_attribute('href'))

# %%
Rating =[]
Review_summary =[]
Full_review = []

"""
for j in page_urls:
    driver.get(j)
    
    
    for i in driver.find_elements_by_xpath("//p[@class='_3LWZlK _1BLPMq']"):
        Rating.append(i.text)
    
    #for i in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']//div//div/div"):
       # Review_summary.append(i.text)
        
    for i in driver.find_elements_by_class_name("t-ZTKy"):
        Review_summary.append(i.text)
    
    for i in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        Full_review.append(i.text)
    time.sleep(2)"""

for page in range(1,13):
    page_url1 = "https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART&page=" + str(page)
    
    driver.get(page_url1)
    
    for i in driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']"):
        Rating.append(i.text)
    
    #for i in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']//div//div/div"):
       # Review_summary.append(i.text)
        
    for i in driver.find_elements_by_class_name("_2-N8zT"):
        Review_summary.append(i.text)
    
    for i in driver.find_elements_by_xpath("//div[@class='t-ZTKy']//div"):
        Full_review.append(i.text)
    time.sleep(2)

# %%
len(Full_review)
# Out:
# 240

# %%
Iphone_review =pd.DataFrame({ })

Iphone_review['Rating']= Rating[:100]
Iphone_review['Review_summary'] = Review_summary[:100]
Iphone_review['Full_review'] =Full_review[:100]
Iphone_review
# Out:
#    Rating         Review_summary  \
# 0       5              Brilliant
# 1       5       Perfect product!
# 2       5          Great product
# 3       5      Worth every penny
# 4       5              Fabulous!
# 5       4            Good choice
# 6       5     Highly recommended
# 7       5       Perfect product!
# 8       5       Perfect product!
# 9       5     Highly recommended
# 10      5       Perfect product!
# 11      5     Highly recommended
# 12      5         Simply awesome
# 13      5      Worth every penny
# 14      5               Terrific
# 15      4           Nice product
# 16      5     Highly recommended
# 17      5         Classy product
# 18      5              Wonderful
# 19      5              Brilliant
# 20      5       Perfect product!
# 21      5              Must buy!
# 22      5      Terrific purchase
# 23      5              Wonderful
# 24      5         Simply awesome
# 25      5  Mind-blowing purchase
# 26      5          Great product
# ...

# %% [markdown]
# Q8: Scrape data for first 100 sneakers you find when you visit flipkart.com and
# search for “sneakers” in the search field.
#
# You have to scrape 4 attributes of each sneaker :
# 1. Brand
# 2. Product Description
# 3. Price
# 4. discount %
# As shown in the below image, you have to scrape the tick marked attributes.

# %%
#lets frist connect the web driver
driver = webdriver.Chrome("chromedriver.exe")

#first get the webpage https://www.flipkart.com/ 
url ="https://www.flipkart.com/"
driver.get(url)

close_login = driver.find_element_by_xpath("//button[@class='_2KpZ6l _2doB4z']")
close_login.click()

#searching sof sungalss in flipkart
search = driver.find_element_by_xpath("//input[@class='_3704LK']")
search.send_keys("sneakers")

submit1 =driver.find_element_by_xpath("//button[@class='L0Z3Pu']")
submit1.click()

# %%
#get all jobs URL inlks
page_urls =[]
url = driver.find_elements_by_xpath("//a[@class='ge-49M']")
for i in url:
    page_urls.append(i.get_attribute('href'))


brand_name =[]
Product_descrption =[]
Price= []
Discount= []

for j in page_urls:
    driver.get(j)
    for i in driver.find_elements_by_xpath("//div[@class='_2WkVRV']"):
        brand_name.append(i.text)
    
    for i in driver.find_elements_by_xpath("//a[@class='IRpwTa']"):
        Product_descrption.append(i.text)
    
    for i in driver.find_elements_by_xpath("//a[@class='IRpwTa']"):
        Product_descrption.append(i.text)

    for i in driver.find_elements_by_xpath("//div[@class='_30jeq3']"):
        Price.append(i.text)
    
    for i in driver.find_elements_by_xpath("//div[@class='_3Ay6Sb']"):
        Discount.append(i.text)
    time.sleep(2)

Sneakers =pd.DataFrame({ })

Sneakers['brand_name']= brand_name[:100]
Sneakers['Product_descrption'] = Product_descrption[:100]
Sneakers['Price'] =Price[:100]
Sneakers['Discount'] =Discount[:100]

Sneakers
# Out:
#                     brand_name  \
# 0                 Foot by Foot
# 1                         PUMA
# 2                      ESSENCE
# 3                  A ANTIC MOP
# 4                       ADIDAS
# 5                         PUMA
# 6                      Crazyly
# 7                        Birde
# 8                         PUMA
# 9                       Bootco
# 10                        PUMA
# 11                       Xtoon
# 12                      Earton
# 13                      DUCATI
# 14                        PUMA
# 15                      BRUTON
# 16                      T-ROCK
# 17                    Skechers
# 18                        PUMA
# 19             U.S. POLO ASSN.
# 20                    RED TAPE
# 21                        PUMA
# 22                        PUMA
# 23                       Echor
# 24                       asics
# 25                      Bonexy
# 26                        PUMA
# 27                       woati
# 28                    RED TAPE
# ...

# %% [markdown]
# Q9: Go to the link - https://www.myntra.com/shoes
#  Set Price filter to “Rs. 6649 to Rs. 13099” , Color filter to “Black”, as shown in
# the below image WEB SCRAPING ASSIGNMENT-2
# .
#
# And then scrape First 100 shoes data you get. The data should include “Brand” of
# the shoes , Short Shoe description, price of the shoe as shown in the below image.

# %%
url ="https://www.myntra.com/shoes"
driver.get(url)

# %%
price_filter =driver.find_element_by_xpath("//ul[@class='price-list']//label/input")
#Click on search button 
price_filter.click()
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-373-56b81c3015c8> in <module>
#       1 price_filter =driver.find_element_by_xpath("//ul[@class='price-list']//label/input")
#       2 #Click on search button
# ----> 3 price_filter.click()
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ...

# %%
import requests, json
from bs4 import BeautifulSoup

headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'}

s = requests.Session()
res = s.get("https://www.myntra.com/sports-shoes/puma/puma-men-blue-hybrid-fuego-running-shoes/11203218/buy", headers=headers, verify=False)

soup = BeautifulSoup(res.text,"lxml")

script = None
for s in soup.find_all("script"):
    if 'pdpData' in s.text:
        script = s.get_text(strip=True)
        break

print(json.loads(script[script.index('{'):]))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# ...

# %%
image_url = []
for i in driver.find_elements_by_xpath("//div[@class='_2QcLo-']/div/div/img"):
    image_url.append(i.get_attribute('src'))
    
image_url
