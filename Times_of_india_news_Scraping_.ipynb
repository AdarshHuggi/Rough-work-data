# %%
# !pip3  install selenium
# !pip3 install webdriver_manager
# !pip3 install lxml
# !pip3 install requests
# !pip3 install beautifulsoup4
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/5f/64/43575537846896abac0b15c3e5ac678d787a4021e906703f1766bfb8ea11/urllib3-1.26.6-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/19/4b/3e96c8ab0eafad2ad0fb8ef43c2201eb7a6fe79ccc04ff8a68480cd2c5cc/webdriver_manager-3.4.2-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/5b/0d/e3fad4ca1de8e70e06444e7d777a5984261e1db98758b5be3e8296c03fe9/crayons-0.4.0-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/92/96/144f70b972a9c0eabbd4391ef93ccd49d0f2747f4f6a2a2738e99e5adc65/requests-2.26.0-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/fd/01/ff260a18caaf4457eb028c96eeb405c4a230ca06c8ec9c1379f813caa52e/configparser-5.0.2-py3-none-any.whl
# ...

# %%
# importing all required library
import pandas as pd

import selenium
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import ElementNotVisibleException
from selenium.common.exceptions import StaleElementReferenceException
from bs4 import BeautifulSoup
import requests

options = webdriver.ChromeOptions()
options.add_argument('--ignore-certificate-errors')
options.add_argument('--ignore-ssl-errors')
driver = webdriver.Chrome("/usr/lib/chromium-browser/chromedriver")

# %%
#accessing the webdriver
driver.get('https://timesofindia.indiatimes.com/archive.cms')
time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-4-868e9a54d41a> in <module>()
#       1 #accessing the webdriver
# ----> 2 driver.get('https://timesofindia.indiatimes.com/archive.cms')
#       3 time.sleep(2)
#
# /home/adarsh/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# /home/adarsh/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
# ...

# %%
#clicking on october month 
october = driver.find_element_by_xpath("/html/body/center/div[1]/div[3]/table[2]/tbody/tr[2]/td[1]/div[3]/table/tbody/tr[1]/td/span/div/strong/a[57]") 
october.click()

# %%
news_url=[]

# %%
#creating empty list
Times_news = { }
Times_news['Date']=[]
Times_news['Vertical']=[]
Times_news['Author']=[]
Times_news['Headline']=[]
Times_news['Description']=[]

# %%
count = 1
for i in range(30):
    try: 
        cal1 =driver_find_element_by_xpath(f"//*[@id='calender']/tbody/tr[2]/td[{count}]/a")
        cal1.click()
    except NoSuchElem

# %%
#geeting only ten day url links 
count =1
row =2
for i in range(9):
    try:
        cal2 = driver.find_element_by_xpath(f"//*[@id='calender']/tbody/tr[{row}]/td[{count}]/a")
        cal2.click()
    except NoSuchElementException:
        row +=1
        count=1
        cal3 = driver.find_element_by_xpath(f"//*[@id='calender']/tbody/tr[{row}]/td[{count}]/a")
        cal3.click()
        
    time.sleep(3)
   
        
    for j in driver.find_elements_by_xpath("/html/body/div/table/tbody/tr/td/div/table/tbody/tr/td/span/a"):
        news_url.append(j.get_attribute('href'))
        
    
    count +=1
    back_oct =driver.find_element_by_xpath("/html/body/div[1]/table[2]/tbody/tr[2]/td[1]/div[2]/a[3]")
    back_oct.click()
    time.sleep(3)

# %%
news_url_10 =pd.DataFrame(news_url)
save = news_url_10.to_csv('news_url.csv')

# %%
news_url
# Out:
# ['http://timesofindia.indiatimes.com//entertainment/malayalam/music/4-musics-never-thought-our-dream-of-working-with-legends-would-happen-so-soon/articleshow/60894096.cms',
#  'http://timesofindia.indiatimes.com//city/kochi/learning-at-the-feet-of-the-master/articleshow/60893274.cms',
#  'http://timesofindia.indiatimes.com//city/kochi/why-spend-a-bomb-on-your-wedding-travel-invest-or-donate-to-charity/articleshow/60892839.cms',
#  'http://timesofindia.indiatimes.com//entertainment/tamil/movies/news/this-is-how-dulquer-and-vikram-became-friends/articleshow/60893081.cms',
#  'http://timesofindia.indiatimes.com//life-style/health-fitness/fitness/gym-fitness-is-not-real/articleshow/60882961.cms',
#  'http://timesofindia.indiatimes.com//city/bhopal/girl-grappler-gifts-a-fracture-to-dangal-ustaad/articleshow/60896754.cms',
#  'http://timesofindia.indiatimes.com//city/bhopal/sand-mining-in-mp-rivers-barring-narmada-begins-today/articleshow/60896750.cms',
# ...

# %%
len(news_url_10)
to_csv= news_url_10.to_csv('news_url_10.csv')

# %%
for i in news_url:
    driver.get(i)
    time.sleep(2)
    
    try:
        date3 = driver.find_element_by_xpath("/html/body/div[2]/div/div[3]/div[4]/div[1]/div[1]/div[2]/span")
        Times_news['Date'].append(date3.text)
        
    except NoSuchElementException:
        date2 = driver.find_element_by_xpath("//*[@id='container']/div[18]/div[4]/div[3]/div[1]/div[2]/div[2]")
        Times_news['Date'].append(date2.text)
        
    else:
        Times_news['Date'].append('-')

        
        
    try:
        h =driver.find_element_by_xpath("//*[@id='container']/div[18]/div[4]/div[3]/div[1]/h1/arttitle")
        Times_news['Headline'].append(h.text)
        
    except NoSuchElementException:
        heading1 =driver.find_element_by_xpath("/html/body/div[2]/div/div[3]/div[5]/div[1]/div[1]/h1/span")
        Times_news['Headline'].append(heading1.text)
        
    else:
        Times_news['Headline'].append('-')
        


    try:
        Author =driver.find_element_by_xpath("/html/body/div[2]/div/div[3]/div[5]/div[1]/div[1]/div[2]/a")
        Times_news['Author'].append(Author.text)
    except:
        Times_news['Author'].append('-')

    try:
        vertical =driver.find_element_by_xpath("/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span")
        Times_news['Vertical'].append(vertical.text)
    except NoSuchElementException:
        vertical1 =driver.find_element_by_xpath("/html/body/div[1]/div[16]/div/div/ol/li[2]/a/span")
        Times_news['Vertical'].append(vertical1.text)
    else:
        Times_news['Vertical'].append('-')
        

    try:
        desc1 =driver.find_element_by_xpath("/html/body/div[2]/div/div[3]/div[5]/div[1]/div[2]/div[1]/div[2]/div[1]/div[1]")
        Times_news['Description'].append(desc1.text)
    except NoSuchElementException:
        desc2 =driver.find_element_by_xpath("/html/body/div[1]/div[18]/div[4]/div[3]/div[2]/div[1]/div[2]/div/arttextxml/div/div")
        Times_news['Description'].append(desc2.text)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-14-ee368b27c60d> in <module>()
#      18     try:
# ---> 19         h =driver.find_element_by_xpath("//*[@id='container']/div[18]/div[4]/div[3]/div[1]/h1/arttitle")
#      20         Times_news['Headline'].append(h.text)
#
# /home/adarsh/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_xpath(self, xpath)
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#
# /home/adarsh/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#
# /home/adarsh/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
# ...

# %%
city =driver.find_element_by_class_name('_1-UZe  JnbfB _3BPhv').getText()
city
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-12-82ca6465d767> in <module>()
#       1
# ----> 2 city =driver.find_element_by_class_name('_1-UZe  JnbfB _3BPhv').getText()
#       3 city
#
# /home/adarsh/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_class_name(self, name)
#     562             element = driver.find_element_by_class_name('foo')
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#     566     def find_elements_by_class_name(self, name):
#
# /home/adarsh/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
# ...

# %%
date =driver.find_element_by_xpath("/html/body/div[2]/div/div[3]/div[5]/div[1]/div[1]/div[2]/span")
Times_news['Date'].append(date.text)


Times_news['Date']
# Out:
# ['Oct 2, 2017, 00:04 IST', 'Oct 2, 2017, 00:04 IST']

# %%
date =driver.find_element_by_xpath("/html/body/div[2]/div/div[3]/div[5]/div[1]/div[1]/div[2]/span")
Times_news['Date'].append(date.text)

heading =driver.find_element_by_xpath("//*[@id='container']/div[18]/div[4]/div[3]/div[1]/h1/arttitle")
Times_news['Headline'].append(heading.text)


try:
    Author =driver.find_element_by_xpath("/html/body/div[2]/div/div[3]/div[5]/div[1]/div[1]/div[2]/a")
    Times_news['Author'].append(Author.text)
except:
    Times_news['Author'].append('-')


Vertical =driver.find_element_by_xpath("/html/body/div[2]/div/div[3]/div[4]/ul/li[2]/a/span")
Times_news['Vertical'].append(Vertical.text)


Desc =driver.find_element_by_xpath("/html/body/div[2]/div/div[3]/div[5]/div[1]/div[2]/div[1]/div[2]/div[1]/div[1]")
Times_news['Description'].append(Desc.text)

# %%
Times_news['Date']
# Out:
# ['Oct 2, 2017, 00:04 IST',
#  'Oct 2, 2017, 00:04 IST',
#  'Oct 2, 2017, 00:04 IST',
#  'Oct 2, 2017, 00:04 IST',
#  '-',
#  'Oct 2, 2017, 00:04 IST',
#  '-',
#  'Created: Oct 1, 2017, 00:00 IST',
#  'Created: Oct 1, 2017, 00:00 IST',
#  'Created: Oct 1, 2017, 00:00 IST',
#  'Created: Oct 1, 2017, 00:00 IST']

# %%
url = "https://timesofindia.indiatimes.com//city/kochi/sculpting-on-a-grand-scale/articleshow/60911418.cms"
print(page.status_code)
page = requests.get(url)
soup = BeautifulSoup (page.text, "html.parser")
# Out:
# 200

# %%
for i in news_url:
    page = requests.get(i)
    soup = BeautifulSoup (page.text, "html.parser")
    
    try:
        headline = soup.h1.text
        TOI['Headline'].append(headline)
    except:
        TOI['Headline'] = '-'
        
    try:
        for item in soup.findAll('div', attrs={'class': 'yYIu- byline'}):
            date = item.find('span').text
            TOI['Date'].append(date)
    except:
        TOI['Date']='-'
            
    try:
        for item in soup.findAll('div', attrs={'class': 'yYIu- byline'}):
            author = item.find('a').text
            TOI['Author'].append(author)
    except:
        TOI['Author']='-'
    
    try:
        for item in soup.findAll('div', attrs={'class': '_3YYSt clearfix'}):
            News_desc = item.text
            TOI['News_desc'].append(News_desc)
    except:
        TOI['News_desc']='-'

# %%
# Out:
# 200

# %%
def get_html(url):
   response = requests.get(url)
   return response.text

# %%
# Out:
# 'Sculpting on a grand scale'

# %%
# Out:
# ' Oct 3, 2017, 00:00 IST'

# %%
# Out:
# 'Deepa Soman / TNN /  Oct 3, 2017, 00:00 IST'

# %%
# Out:
# 'Making little designs on wooden doors was the favourite pastime of Chithra E G, during her childhood in Kummanode in Ernakulam.  Though she wasnâ\x80\x99t one of those academically bright students with dreams to be an engineer or a doctor, she gradually became aware that her destiny was to be an artist. The yearning to be one motivated her to finish school and join RLV College of Music and Fine Arts, but what awaited her there was something she didnâ\x80\x99t foresee. â\x80\x9cI discovered a course in sculpting at the college and when I heard about it, curiosity got the better of me. I researched more about it and soon, I felt that this was my calling. I guess it was also because my dad was a carpenter and the knack to make art out of nothing was there in my blood,â\x80\x9d recalls the 31-year-old. It was her first step towards becoming one of the few woman sculptors of Kerala. She is now a familiar name in the field with more than eight years of experience.  Chithra, who has been p
# ...

# %%
for item1 in soup.findAll('li', attrs={'class': '_1-UZe  JnbfB _3BPhv'}):
    vertical1 = item1.find("a").text

# %%
vertical1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-be547990702e> in <module>()
# ----> 1 vertical1
#
# NameError: name 'vertical1' is not defined

# %%
def get_all_items(html):
    soup = BeautifulSoup(html, 'lxml')
    items = soup.find("ul", {"class": "b-list__items_nofooter"}).findAll("li", {"class": "s-item"})
    return items

# %%
def get_item_data(item):
    try:
          title = item.find({"h3": "b-s-item__title"}).text
    except:
          title = ''
    try:
          price = item.find("span", {"class": "s-item__price"}).text
    except:
          price = ''
    data = {'title': title,
            'price': price}
    return data

# %%
def write_csv(i, data):
    with open('notebooks.csv', 'a') as f:
        writer = csv.writer(f)
        writer.writerow((data['title'],
        data['price']))
        print(i, data['title'], 'parsed')

# %%
def main():
   url = 'https://www.ebay.com/b/Laptops-Netbooks/175672/bn_1648276'
   for page in range(1, 5):  # count of pages to parse
       all_items = get_all_items(get_html(url + '?_pgn={}'.format(page)))
       for i, item in enumerate(all_items):
           data = get_item_data(item)
           write_csv(i, data)


if __name__ == '__main__':
   main()

# %%
def get_prices(line):
    try:
        seller = line.find_element_by_class_name('seller__name').text.strip()
    except:
        seller = ''
    try:
        listing_condition = line.find_element_by_class_name(
            'product-listing__condition').text.strip().lower()
    except:
        listing_condition = ''
    try:
        price = line.find_element_by_class_name('product-listing__price')
    except:
        price = ''
    price = price.text
    price = float(price.replace('$', '').replace(',', ''))
    data = {'seller': seller,
            'listing_condition': listing_condition,
            'price': price}
    write_csv(data)
